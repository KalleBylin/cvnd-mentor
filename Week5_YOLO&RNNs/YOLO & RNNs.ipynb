# %% [markdown]
# # Week 5: YOLO & RNNs

# %% [markdown]
# This week:
# - YOLO
# - NLP & Word embeddings
# - RNNs

# %% [markdown]
# ## YOLO

# %% [markdown]
# **R-CNN**
#
# ![RCNN](https://camo.githubusercontent.com/05d3c1a11df05588eb567346e896efa92cf3c131/68747470733a2f2f63646e2d696d616765732d312e6d656469756d2e636f6d2f6d61782f313630302f302a53646a36734b445251795a704f366f482e)
#
# - Previous: Sliding windows
# - R-CNN: Region proposals
# - Fast R-CNN: Region proposals in deeper layer
# - Faster R-CNN: region proposal network (RPN) for generating region proposals

# %% [markdown]
# |  | PASCAL 2007 mAP | Speed 1 | Speed 2 |
# |--|-----------------|-----------|--------------|
# |R-CNN | 66.0 | 0.07 FPS | 20 s/img |
# |Fast R-CNN | 70.0 | 0.05 FPS | 2 s/img |
# |Faster R-CNN | 73.2.0 | 7 FPS | 140 ms/img |
# |YOLO | 69.0 | 45 FPS | 22 ms/img |

# %% [markdown]
# We divide the image into a 13x13 grid:
#
# ![Grid](https://camo.githubusercontent.com/4338301d905b87a1e9d8a4b68b63775d30adcf15/687474703a2f2f6d616368696e657468696e6b2e6e65742f696d616765732f796f6c6f2f477269644032782e706e67)

# %% [markdown]
# The model predicts bounding boxes and the confidence of each box according to P(Object)
#
# ![Boxes](http://machinethink.net/images/yolo/Boxes@2x.png)

# %% [markdown]
# The model also calculates a conditioned probability: For example P(Car|Object)
#
#
# ![Conditional](https://www.renom.jp/notebooks/tutorial/image_processing/yolo/yolo006.png)

# %% [markdown]
# The previous two are multiplied:
#
# ![Multiply](https://machinethink.net/images/yolo/Scores@2x.png)

# %% [markdown]
# Some of the confidences are not very high so we threshold by applying NMS:
#
# ![NMS](https://camo.githubusercontent.com/57cf362cc6d1ce644282864edf499e8613ca7a7d/687474703a2f2f706a7265646469652e636f6d2f6d656469612f696d6167652f66696e616c2e706e67)

# %% [markdown]
# Here you can see how the YOLO architecture looks like:
#
# ![YOLO](https://camo.githubusercontent.com/3c2151338f97e8494cb208d46a29bab4763c7dd6/68747470733a2f2f692e696d6775722e636f6d2f5148304376524e2e706e67)

# %% [markdown]
# ## NLP

# %% [markdown]
# ### What is going on here?
#
# ![Translate](images/google-translate.jpg)

# %% [markdown]
# ### What about here?
#
# ![Linkedin](images/smart-replies.jpg)

# %% [markdown]
# ### We have an issue here
#
# ![Text data](images/text-data.jpg)

# %%
# King - Man + Woman = ?

king = 'King'
man = 'Man'
woman = 'Woman'

# %%
king - man + woman
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f8b63aedf012> in <module>()
# ----> 1 king - man + woman
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ## Word Embeddings

# %%
from tensorflow.python.keras.preprocessing.text import Tokenizer

texts = ['We are now in week five of this computer vision nanodegree program by Udacity',
         'Udacity has several interesting courses, including NLP and computer vision']

# %%
t = Tokenizer(num_words=15) # num_words -> Vocablury size
t.fit_on_texts(texts)

# %%
# We can now take a look into what the tokenizer found

t.document_count #Number of documents Tokenizer got fit on

# %%
t.word_counts  #Each word and how many times they appeared across all docs

# %%
t.word_index #Unique index of each word in Tokenizer

# %%
t.word_docs #How many documents a word appeared in

# %% [markdown]
# **We can also use the tokenizer to convert our texts into matrices**

# %%
t.texts_to_matrix(texts)

# %%
t.texts_to_matrix(texts,mode='count')

# %% [markdown]
# This tells us if a word is present in a particular text but doesn't give us information about context.
#
# **Examples:**
#
# - My friend caught a big fish vs A big fish caught my friend
# - I went to high school in Spain and have been living in Colombia for 8 years. I am probably fluent in ...?

# %%
import pandas as pd
import re, string
import gensim
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# C:\Users\Kalle\Anaconda3\envs\fastai\lib\site-packages\smart_open\ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')

# %% [markdown]
# Data can be downloaded from Kaggle at the following URL
#
# - https://www.kaggle.com/c/word2vec-nlp-tutorial/data

# %%
df = pd.read_csv('unlabeledTrainData.tsv.zip', header=0, delimiter="\t", quoting=3)

df.shape
# Out:
# (50000, 2)

# %%
df.head()
# Out:
#           id                                             review
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...

# %%
def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)	
  except:
    return ""

df['clean_review'] = df['review'].apply(clean_str)

df.head()
# Out:
#           id                                             review  \
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...
#
#                                         clean_review
# 0  watching time chasers it obvious that it was m...
# 1  i saw this film about years ago and remember i...
# 2  minor spoilers br br in new york joan barnard ...
# 3  i went to see this film with a great deal of e...
# 4  yes i agree with everyone on this site this mo...

# %%
documents = []

for doc in df['clean_review']:
    documents.append(doc.split(' '))
    
model = gensim.models.Word2Vec(documents, #Word list
                               min_count=10, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPUs
                               size=50,  #Embedding size
                               window=5, #Maximum Distance between current and predicted word
                               iter=10   #Number of iterations over the text corpus
                              )
# Out:
# 2019-04-24 16:55:20,918 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-04-24 16:55:20,926 : INFO : collecting all words and their counts
# 2019-04-24 16:55:20,930 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-04-24 16:55:23,975 : INFO : PROGRESS: at sentence #10000, processed 2399440 words, keeping 51654 word types
# 2019-04-24 16:55:27,656 : INFO : PROGRESS: at sentence #20000, processed 4835846 words, keeping 69077 word types
# 2019-04-24 16:55:31,039 : INFO : PROGRESS: at sentence #30000, processed 7267977 words, keeping 81515 word types
# 2019-04-24 16:55:38,030 : INFO : PROGRESS: at sentence #40000, processed 9669772 words, keeping 91685 word types
words/s, in_qsize 7, out_qsize 0
# 2019-04-24 17:02:21,512 : INFO : EPOCH 10 - PROGRESS: at 73.81% examples, 265973 words/s, in_qsize 7, out_qsize 0
# 2019-04-24 17:02:22,515 : INFO : EPOCH 10 - PROGRESS: at 76.88% examples, 266213 words/s, in_qsize 8, out_qsize 0
# 2019-04-24 17:02:23,538 : INFO : EPOCH 10 - PROGRESS: at 80.22% examples, 266714 words/s, in_qsize 8, out_qsize 0
# 2019-04-24 17:02:24,546 : INFO : EPOCH 10 - PROGRESS: at 82.85% examples, 265523 words/s, in_qsize 7, out_qsize 0
# 2019-04-24 17:02:25,558 : INFO : EPOCH 10 - PROGRESS: at 85.35% examples, 263695 words/s, in_qsize 7, out_qsize 0
# 2019-04-24 17:02:26,592 : INFO : EPOCH 10 - PROGRESS: at 87.84% examples, 261742 words/s, in_qsize 7, out_qsize 0
# 2019-04-24 17:02:27,616 : INFO : EPOCH 10 - PROGRESS: at 90.51% examples, 260718 words/s, in_qsize 8, out_qsize 0
# 2019-04-24 17:02:28,617 : INFO : EPOCH 10 - PROGRESS: at 93.16% examples, 259918 words/s, in_qsize 7, out_qsize 0
# 2019-04-24 17:02:29,656 : INFO : EPOCH 10 - PROGRESS: at 96.17% examples, 259949 words/s, in_qsize 7, out_qsize 0
# 2019-04-24 17:02:30,681 : INFO : EPOCH 10 - PROGRESS: at 99.32% examples, 260106 words/s, in_qsize 8, out_qsize 1
# 2019-04-24 17:02:30,853 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-24 17:02:30,864 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-24 17:02:30,886 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-24 17:02:30,922 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-24 17:02:30,933 : INFO : EPOCH - 10 : training on 12084660 raw words (8815783 effective words) took 33.9s, 259935 effective words/s
# 2019-04-24 17:02:30,942 : INFO : training on a 120846600 raw words (88169759 effective words) took 404.2s, 218127 effective words/s

# %%
model.wv.syn0.shape
# Out:
# C:\Users\Kalle\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   """Entry point for launching an IPython kernel.
# (28322, 50)

# %%
model.wv.vocab
# Out:
# {'watching': <gensim.models.keyedvectors.Vocab at 0x1fef1729e48>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1fef1729e80>,
#  'chasers': <gensim.models.keyedvectors.Vocab at 0x1fef174a048>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x1fef174a0f0>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x1fef174a080>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x1fef174a0b8>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x1fef174a160>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1fef174a198>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x1fef174a1d0>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x1fef174a208>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x1fef174a240>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x1fef174a278>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x1fef174a2b0>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x1fef174a2e8>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x1fef174a320>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x1fef174a358>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x1fef174a390>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1fef174a3c8>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1fef174a400>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1fef174a438>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x1fef174a470>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x1fef174a4a8>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x1fef174a4e0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x1fef174a518>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x1fef174a550>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x1fef174a588>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x1fef174a5c0>,
#  's': <gensim.models.keyedvectors.Vocab at 0x1fef174a5f8>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x1fef174a630>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x1fef174a668>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x1fef174a6a0>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x1fef174a6d8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1fef174a710>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x1fef174a748>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x1fef174a780>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x1fef174a7b8>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x1fef174a7f0>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x1fef174a828>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1fef174a860>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x1fef174a898>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x1fef174a8d0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1fef174a908>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x1fef174a940>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x1fef174a978>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x1fef174a9b0>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x1fef174a9e8>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x1fef174aa20>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x1fef174aa58>,
#  'lame': <gensim.models.keyedvectors.Vocab at 0x1fef174aa90>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x1fef174aac8>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x1fef174ab00>,
#  'cinematography': <gensim.models.keyedvectors.Vocab at 0x1fef174ab38>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x1fef174ab70>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x1fef174aba8>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x1fef174abe0>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x1fef174ac18>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x1fef174ac50>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x1fef174ac88>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x1fef174acc0>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x1fef174acf8>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x1fef174ad30>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x1fef174ad68>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1fef174ada0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x1fef174add8>,
#  'prevented': <gensim.models.keyedvectors.Vocab at 0x1fef174ae10>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x1fef174ae48>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x1fef174ae80>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1fef174aeb8>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x1fef174aef0>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x1fef174af28>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x1fef174af60>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x1fef174af98>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x1fef174afd0>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x1fef174c048>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x1fef174c080>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x1fef174c0b8>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x1fef174c0f0>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x1fef174c128>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x1fef174c160>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x1fef174c198>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x1fef174c1d0>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x1fef174c208>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1fef174c240>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x1fef174c278>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x1fef174c2b0>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1fef174c2e8>,
#  'breaks': <gensim.models.keyedvectors.Vocab at 0x1fef174c320>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x1fef174c358>,
#  'nurses': <gensim.models.keyedvectors.Vocab at 0x1fef174c390>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x1fef174c3c8>,
#  'rapes': <gensim.models.keyedvectors.Vocab at 0x1fef174c400>,
#  'tortures': <gensim.models.keyedvectors.Vocab at 0x1fef174c438>,
#  'kills': <gensim.models.keyedvectors.Vocab at 0x1fef174c470>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x1fef174c4a8>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x1fef174c4e0>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x1fef174c518>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x1fef174c550>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x1fef174c588>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x1fef174c5c0>,
#  'saves': <gensim.models.keyedvectors.Vocab at 0x1fef174c5f8>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x1fef174c630>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1fef174c668>,
#  'shocking': <gensim.models.keyedvectors.Vocab at 0x1fef174c6a0>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x1fef174c6d8>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x1fef174c710>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1fef174c748>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x1fef174c780>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x1fef174c7b8>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x1fef174c7f0>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x1fef174c828>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x1fef174c860>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x1fef174c898>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x1fef174c8d0>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x1fef174c908>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x1fef174c940>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x1fef174c978>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x1fef174c9b0>,
#  'obscene': <gensim.models.keyedvectors.Vocab at 0x1fef174c9e8>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x1fef174ca20>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x1fef174ca58>,
#  'spoilers': <gensim.models.keyedvectors.Vocab at 0x1fef174ca90>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1fef174cac8>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x1fef174cb00>,
#  'joan': <gensim.models.keyedvectors.Vocab at 0x1fef174cb38>,
#  'barnard': <gensim.models.keyedvectors.Vocab at 0x1fef174cb70>,
#  'elvire': <gensim.models.keyedvectors.Vocab at 0x1fef174cba8>,
#  'audrey': <gensim.models.keyedvectors.Vocab at 0x1fef174cbe0>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x1fef174cc18>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x1fef174cc50>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x1fef174cc88>,
#  'arthur': <gensim.models.keyedvectors.Vocab at 0x1fef174ccc0>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x1fef174ccf8>,
#  'saxon': <gensim.models.keyedvectors.Vocab at 0x1fef174cd30>,
#  'mysteriously': <gensim.models.keyedvectors.Vocab at 0x1fef174cd68>,
#  'murdered': <gensim.models.keyedvectors.Vocab at 0x1fef174cda0>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x1fef174cdd8>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x1fef174ce10>,
#  'searching': <gensim.models.keyedvectors.Vocab at 0x1fef174ce48>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x1fef174ce80>,
#  'etruscan': <gensim.models.keyedvectors.Vocab at 0x1fef174ceb8>,
#  'tomb': <gensim.models.keyedvectors.Vocab at 0x1fef174cef0>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x1fef174cf28>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x1fef174cf60>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x1fef174cf98>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x1fef174cfd0>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x1fef174f048>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x1fef174f080>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x1fef174f0b8>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x1fef174f0f0>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x1fef174f128>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x1fef174f160>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x1fef174f198>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x1fef174f1d0>,
#  'visions': <gensim.models.keyedvectors.Vocab at 0x1fef174f208>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x1fef174f240>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x1fef174f278>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x1fef174f2b0>,
#  'maggots': <gensim.models.keyedvectors.Vocab at 0x1fef174f2e8>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x1fef174f320>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x1fef174f358>,
#  'shootings': <gensim.models.keyedvectors.Vocab at 0x1fef174f390>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x1fef174f3c8>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x1fef174f400>,
#  'realizes': <gensim.models.keyedvectors.Vocab at 0x1fef174f438>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x1fef174f470>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x1fef174f4a8>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x1fef174f4e0>,
#  'dealer': <gensim.models.keyedvectors.Vocab at 0x1fef174f518>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x1fef174f550>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1fef174f588>,
#  'drugs': <gensim.models.keyedvectors.Vocab at 0x1fef174f5c0>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x1fef174f5f8>,
#  'detective': <gensim.models.keyedvectors.Vocab at 0x1fef174f630>,
#  'narcotic': <gensim.models.keyedvectors.Vocab at 0x1fef174f668>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x1fef174f6a0>,
#  'ends': <gensim.models.keyedvectors.Vocab at 0x1fef174f6d8>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x1fef174f710>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x1fef174f748>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x1fef174f780>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x1fef174f7b8>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x1fef174f7f0>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x1fef174f828>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x1fef174f860>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x1fef174f898>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x1fef174f8d0>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x1fef174f908>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x1fef174f940>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x1fef174f978>,
#  'displeasure': <gensim.models.keyedvectors.Vocab at 0x1fef174f9b0>,
#  'wasting': <gensim.models.keyedvectors.Vocab at 0x1fef174f9e8>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x1fef174fa20>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x1fef174fa58>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x1fef174fa90>,
#  'absurd': <gensim.models.keyedvectors.Vocab at 0x1fef174fac8>,
#  'mixing': <gensim.models.keyedvectors.Vocab at 0x1fef174fb00>,
#  'thriller': <gensim.models.keyedvectors.Vocab at 0x1fef174fb38>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x1fef174fb70>,
#  'supernatural': <gensim.models.keyedvectors.Vocab at 0x1fef174fba8>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x1fef174fbe0>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1fef174fc18>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1fef174fc50>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x1fef174fc88>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x1fef174fcc0>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x1fef174fcf8>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x1fef174fd30>,
#  'highlighting': <gensim.models.keyedvectors.Vocab at 0x1fef174fd68>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x1fef174fda0>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x1fef174fdd8>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x1fef174fe10>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x1fef174fe48>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x1fef174fe80>,
#  'credits': <gensim.models.keyedvectors.Vocab at 0x1fef174feb8>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x1fef174fef0>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x1fef174ff28>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x1fef174ff60>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x1fef174ff98>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x1fef174ffd0>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x1fef1753048>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x1fef1753080>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x1fef17530b8>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x1fef17530f0>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x1fef1753128>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x1fef1753160>,
#  'direction': <gensim.models.keyedvectors.Vocab at 0x1fef1753198>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x1fef17531d0>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x1fef1753208>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x1fef1753240>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x1fef1753278>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x1fef17532b0>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x1fef17532e8>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x1fef1753320>,
#  'desire': <gensim.models.keyedvectors.Vocab at 0x1fef1753358>,
#  'curiosity': <gensim.models.keyedvectors.Vocab at 0x1fef1753390>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x1fef17533c8>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x1fef1753400>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x1fef1753438>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x1fef1753470>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x1fef17534a8>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x1fef17534e0>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x1fef1753518>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x1fef1753550>,
#  'navigate': <gensim.models.keyedvectors.Vocab at 0x1fef1753588>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x1fef17535c0>,
#  'gym': <gensim.models.keyedvectors.Vocab at 0x1fef17535f8>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x1fef1753630>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x1fef1753668>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x1fef17536a0>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x1fef17536d8>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x1fef1753710>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x1fef1753748>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1fef1753780>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x1fef17537b8>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x1fef17537f0>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x1fef1753828>,
#  'mist': <gensim.models.keyedvectors.Vocab at 0x1fef1753860>,
#  'rio': <gensim.models.keyedvectors.Vocab at 0x1fef1753898>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x1fef17538d0>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x1fef1753908>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1fef1753940>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1fef1753978>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x1fef17539b0>,
#  'excitement': <gensim.models.keyedvectors.Vocab at 0x1fef17539e8>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x1fef1753a20>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x1fef1753a58>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1fef1753a90>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x1fef1753ac8>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x1fef1753b00>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x1fef1753b38>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x1fef1753b70>,
#  'stinks': <gensim.models.keyedvectors.Vocab at 0x1fef1753be0>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x1fef1753c18>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x1fef1753c50>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x1fef1753c88>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x1fef1753cc0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1fef1753cf8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x1fef1753d30>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x1fef1753d68>,
#  'walked': <gensim.models.keyedvectors.Vocab at 0x1fef1753da0>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x1fef1753dd8>,
#  'pub': <gensim.models.keyedvectors.Vocab at 0x1fef1753e10>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1fef1753e48>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x1fef1753e80>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x1fef1753eb8>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x1fef1753ef0>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x1fef1753f28>,
#  'balcony': <gensim.models.keyedvectors.Vocab at 0x1fef1753f60>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x1fef1753f98>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x1fef1753fd0>,
#  'helicopter': <gensim.models.keyedvectors.Vocab at 0x1fef1755048>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x1fef1755080>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x1fef17550b8>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x1fef17550f0>,
#  't': <gensim.models.keyedvectors.Vocab at 0x1fef1755128>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x1fef1755160>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x1fef1755198>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x1fef17551d0>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x1fef1755208>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x1fef1755240>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x1fef1755278>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x1fef17552b0>,
#  'reporters': <gensim.models.keyedvectors.Vocab at 0x1fef17552e8>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x1fef1755320>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x1fef1755358>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x1fef1755390>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x1fef17553c8>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x1fef1755400>,
#  'jumping': <gensim.models.keyedvectors.Vocab at 0x1fef1755438>,
#  'encouraging': <gensim.models.keyedvectors.Vocab at 0x1fef1755470>,
#  'copy': <gensim.models.keyedvectors.Vocab at 0x1fef17554a8>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x1fef17554e0>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x1fef1755518>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x1fef1755550>,
#  'circumstances': <gensim.models.keyedvectors.Vocab at 0x1fef1755588>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x1fef17555c0>,
#  'broadcasts': <gensim.models.keyedvectors.Vocab at 0x1fef17555f8>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1fef1755630>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x1fef1755668>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x1fef17556a0>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x1fef17556d8>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x1fef1755710>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x1fef1755748>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x1fef1755780>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x1fef17557b8>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1fef17557f0>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x1fef1755828>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x1fef1755860>,
#  'microphone': <gensim.models.keyedvectors.Vocab at 0x1fef1755898>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x1fef17558d0>,
#  'transmitter': <gensim.models.keyedvectors.Vocab at 0x1fef1755908>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x1fef1755940>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x1fef1755978>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x1fef17559b0>,
#  'utterly': <gensim.models.keyedvectors.Vocab at 0x1fef17559e8>,
#  'derivative': <gensim.models.keyedvectors.Vocab at 0x1fef1755a20>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x1fef1755a58>,
#  'existent': <gensim.models.keyedvectors.Vocab at 0x1fef1755a90>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1fef1755ac8>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x1fef1755b00>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x1fef1755b38>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x1fef1755b70>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x1fef1755ba8>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x1fef1755be0>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x1fef1755c18>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x1fef1755c50>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x1fef1755c88>,
#  'compares': <gensim.models.keyedvectors.Vocab at 0x1fef1755cc0>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x1fef1755cf8>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x1fef1755d30>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x1fef1755d68>,
#  'describes': <gensim.models.keyedvectors.Vocab at 0x1fef1755da0>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x1fef1755dd8>,
#  'packaging': <gensim.models.keyedvectors.Vocab at 0x1fef1755e10>,
#  'intentionally': <gensim.models.keyedvectors.Vocab at 0x1fef1755e48>,
#  'misleading': <gensim.models.keyedvectors.Vocab at 0x1fef1755e80>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1fef1755eb8>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x1fef1755ef0>,
#  'describe': <gensim.models.keyedvectors.Vocab at 0x1fef1755f28>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x1fef1755f60>,
#  'retitled': <gensim.models.keyedvectors.Vocab at 0x1fef1755f98>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x1fef1755fd0>,
#  'goofy': <gensim.models.keyedvectors.Vocab at 0x1fef1759048>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x1fef1759080>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x1fef17590b8>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x1fef17590f0>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x1fef1759128>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x1fef1759160>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x1fef1759198>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x1fef17591d0>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x1fef1759208>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x1fef1759240>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x1fef1759278>,
#  'locate': <gensim.models.keyedvectors.Vocab at 0x1fef17592b0>,
#  'rodney': <gensim.models.keyedvectors.Vocab at 0x1fef17592e8>,
#  'dangerfield': <gensim.models.keyedvectors.Vocab at 0x1fef1759320>,
#  'comedians': <gensim.models.keyedvectors.Vocab at 0x1fef1759358>,
#  'hbo': <gensim.models.keyedvectors.Vocab at 0x1fef1759390>,
#  'featured': <gensim.models.keyedvectors.Vocab at 0x1fef17593c8>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1fef1759400>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x1fef1759438>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x1fef1759470>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x1fef17594a8>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x1fef17594e0>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x1fef1759518>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x1fef1759550>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x1fef1759588>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1fef17595c0>,
#  'carrey': <gensim.models.keyedvectors.Vocab at 0x1fef17595f8>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x1fef1759630>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x1fef1759668>,
#  'annoying': <gensim.models.keyedvectors.Vocab at 0x1fef17596a0>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x1fef17596d8>,
#  'lacking': <gensim.models.keyedvectors.Vocab at 0x1fef1759710>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x1fef1759748>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x1fef1759780>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1fef17597b8>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x1fef17597f0>,
#  'comedian': <gensim.models.keyedvectors.Vocab at 0x1fef1759828>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1fef1759860>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x1fef1759898>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x1fef17598d0>,
#  'janet': <gensim.models.keyedvectors.Vocab at 0x1fef1759908>,
#  'talented': <gensim.models.keyedvectors.Vocab at 0x1fef1759940>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x1fef1759978>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x1fef17599b0>,
#  'beware': <gensim.models.keyedvectors.Vocab at 0x1fef17599e8>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x1fef1759a20>,
#  'advertising': <gensim.models.keyedvectors.Vocab at 0x1fef1759a58>,
#  'jennifer': <gensim.models.keyedvectors.Vocab at 0x1fef1759a90>,
#  'ehle': <gensim.models.keyedvectors.Vocab at 0x1fef1759ac8>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x1fef1759b00>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x1fef1759b38>,
#  'prejudice': <gensim.models.keyedvectors.Vocab at 0x1fef1759b70>,
#  'jeremy': <gensim.models.keyedvectors.Vocab at 0x1fef1759ba8>,
#  'northam': <gensim.models.keyedvectors.Vocab at 0x1fef1759be0>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x1fef1759c18>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x1fef1759c50>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x1fef1759c88>,
#  'actors': <gensim.models.keyedvectors.Vocab at 0x1fef1759cc0>,
#  'caliber': <gensim.models.keyedvectors.Vocab at 0x1fef1759cf8>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x1fef1759d30>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x1fef1759d68>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x1fef1759da0>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x1fef1759dd8>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x1fef1759e10>,
#  'sequences': <gensim.models.keyedvectors.Vocab at 0x1fef1759e48>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x1fef1759e80>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x1fef1759eb8>,
#  'eager': <gensim.models.keyedvectors.Vocab at 0x1fef1759ef0>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x1fef1759f28>,
#  'disappointment': <gensim.models.keyedvectors.Vocab at 0x1fef1759f60>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x1fef1759f98>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x1fef1759fd0>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x1fef175e048>,
#  'flick': <gensim.models.keyedvectors.Vocab at 0x1fef175e080>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x1fef175e0b8>,
#  'scenes': <gensim.models.keyedvectors.Vocab at 0x1fef175e0f0>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x1fef175e128>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x1fef175e160>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x1fef175e198>,
#  'tenderness': <gensim.models.keyedvectors.Vocab at 0x1fef175e1d0>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x1fef175e208>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x1fef175e240>,
#  'consisted': <gensim.models.keyedvectors.Vocab at 0x1fef175e278>,
#  'hackneyed': <gensim.models.keyedvectors.Vocab at 0x1fef175e2b0>,
#  'unsubtle': <gensim.models.keyedvectors.Vocab at 0x1fef175e2e8>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x1fef175e320>,
#  'cinematic': <gensim.models.keyedvectors.Vocab at 0x1fef175e358>,
#  'lust': <gensim.models.keyedvectors.Vocab at 0x1fef175e390>,
#  'voracious': <gensim.models.keyedvectors.Vocab at 0x1fef175e3c8>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x1fef175e400>,
#  'mouthed': <gensim.models.keyedvectors.Vocab at 0x1fef175e438>,
#  'kissing': <gensim.models.keyedvectors.Vocab at 0x1fef175e470>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x1fef175e4a8>,
#  'porn': <gensim.models.keyedvectors.Vocab at 0x1fef175e4e0>,
#  'humping': <gensim.models.keyedvectors.Vocab at 0x1fef175e518>,
#  'entertaining': <gensim.models.keyedvectors.Vocab at 0x1fef175e550>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x1fef175e588>,
#  'originality': <gensim.models.keyedvectors.Vocab at 0x1fef175e5c0>,
#  'tasteless': <gensim.models.keyedvectors.Vocab at 0x1fef175e5f8>,
#  'awful': <gensim.models.keyedvectors.Vocab at 0x1fef175e630>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x1fef175e668>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x1fef175e6a0>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x1fef175e6d8>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x1fef175e710>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x1fef175e748>,
#  'romance': <gensim.models.keyedvectors.Vocab at 0x1fef175e780>,
#  'effeminate': <gensim.models.keyedvectors.Vocab at 0x1fef175e7b8>,
#  'appearance': <gensim.models.keyedvectors.Vocab at 0x1fef175e7f0>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x1fef175e828>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x1fef175e860>,
#  'aren': <gensim.models.keyedvectors.Vocab at 0x1fef175e898>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x1fef175e8d0>,
#  'masculine': <gensim.models.keyedvectors.Vocab at 0x1fef175e908>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x1fef175e940>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x1fef175e978>,
#  'hollywood': <gensim.models.keyedvectors.Vocab at 0x1fef175e9b0>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x1fef175e9e8>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x1fef175ea20>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x1fef175ea58>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x1fef175ea90>,
#  'imaginative': <gensim.models.keyedvectors.Vocab at 0x1fef175eac8>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x1fef175eb00>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x1fef175eb38>,
#  'amy': <gensim.models.keyedvectors.Vocab at 0x1fef175eb70>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x1fef175eba8>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x1fef175ebe0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x1fef175ec18>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x1fef175ec50>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1fef175ec88>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1fef175ecc0>,
#  'publisher': <gensim.models.keyedvectors.Vocab at 0x1fef175ecf8>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x1fef175ed30>,
#  'guiding': <gensim.models.keyedvectors.Vocab at 0x1fef175ed68>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x1fef175eda0>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x1fef175edd8>,
#  'tour': <gensim.models.keyedvectors.Vocab at 0x1fef175ee10>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1fef175ee48>,
#  'susan': <gensim.models.keyedvectors.Vocab at 0x1fef175ee80>,
#  'sarandon': <gensim.models.keyedvectors.Vocab at 0x1fef175eeb8>,
#  'plays': <gensim.models.keyedvectors.Vocab at 0x1fef175eef0>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x1fef175ef28>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x1fef175ef60>,
#  'sadistic': <gensim.models.keyedvectors.Vocab at 0x1fef175ef98>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x1fef175efd0>,
#  'billy': <gensim.models.keyedvectors.Vocab at 0x1fef1761048>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x1fef1761080>,
#  'thorton': <gensim.models.keyedvectors.Vocab at 0x1fef17610b8>,
#  'chubby': <gensim.models.keyedvectors.Vocab at 0x1fef17610f0>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x1fef1761128>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x1fef1761160>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x1fef1761198>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x1fef17611d0>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x1fef1761208>,
#  'actress': <gensim.models.keyedvectors.Vocab at 0x1fef1761240>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x1fef1761278>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x1fef17612b0>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x1fef17612e8>,
#  'gown': <gensim.models.keyedvectors.Vocab at 0x1fef1761320>,
#  'wears': <gensim.models.keyedvectors.Vocab at 0x1fef1761358>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x1fef1761390>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x1fef17613c8>,
#  'festival': <gensim.models.keyedvectors.Vocab at 0x1fef1761400>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x1fef1761438>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x1fef1761470>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1fef17614a8>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x1fef17614e0>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x1fef1761518>,
#  'stale': <gensim.models.keyedvectors.Vocab at 0x1fef1761550>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x1fef1761588>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x1fef17615c0>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x1fef17615f8>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x1fef1761630>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x1fef1761668>,
#  'adopts': <gensim.models.keyedvectors.Vocab at 0x1fef17616a0>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x1fef17616d8>,
#  'contradicts': <gensim.models.keyedvectors.Vocab at 0x1fef1761710>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x1fef1761748>,
#  've': <gensim.models.keyedvectors.Vocab at 0x1fef1761780>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x1fef17617b8>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x1fef17617f0>,
#  'erase': <gensim.models.keyedvectors.Vocab at 0x1fef1761828>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x1fef1761860>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x1fef1761898>,
#  'carrying': <gensim.models.keyedvectors.Vocab at 0x1fef17618d0>,
#  'employees': <gensim.models.keyedvectors.Vocab at 0x1fef1761908>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x1fef1761940>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x1fef1761978>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x1fef17619b0>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x1fef17619e8>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x1fef1761a20>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x1fef1761a58>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x1fef1761a90>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x1fef1761ac8>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x1fef1761b00>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x1fef1761b38>,
#  'northwest': <gensim.models.keyedvectors.Vocab at 0x1fef1761b70>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x1fef1761ba8>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x1fef1761be0>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x1fef1761c18>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x1fef1761c50>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x1fef1761c88>,
#  'harlan': <gensim.models.keyedvectors.Vocab at 0x1fef1761cc0>,
#  'knowles': <gensim.models.keyedvectors.Vocab at 0x1fef1761cf8>,
#  'lance': <gensim.models.keyedvectors.Vocab at 0x1fef1761d30>,
#  'henriksen': <gensim.models.keyedvectors.Vocab at 0x1fef1761d68>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x1fef1761da0>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1fef1761dd8>,
#  'ragtag': <gensim.models.keyedvectors.Vocab at 0x1fef1761e10>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x1fef1761e48>,
#  'execute': <gensim.models.keyedvectors.Vocab at 0x1fef1761e80>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x1fef1761eb8>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x1fef1761ef0>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x1fef1761f28>,
#  'oy': <gensim.models.keyedvectors.Vocab at 0x1fef1761f60>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x1fef1761f98>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x1fef1761fd0>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x1fef1764048>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x1fef1764080>,
#  'genre': <gensim.models.keyedvectors.Vocab at 0x1fef17640b8>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x1fef17640f0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x1fef1764128>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x1fef1764160>,
#  'suffers': <gensim.models.keyedvectors.Vocab at 0x1fef1764198>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1fef17641d0>,
#  'flaws': <gensim.models.keyedvectors.Vocab at 0x1fef1764208>,
#  're': <gensim.models.keyedvectors.Vocab at 0x1fef1764240>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x1fef1764278>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x1fef17642b0>,
#  'jonas': <gensim.models.keyedvectors.Vocab at 0x1fef17642e8>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x1fef1764320>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x1fef1764358>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x1fef1764390>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x1fef17643c8>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x1fef1764400>,
#  'aka': <gensim.models.keyedvectors.Vocab at 0x1fef1764438>,
#  'sasquatch': <gensim.models.keyedvectors.Vocab at 0x1fef1764470>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x1fef17644a8>,
#  'editing': <gensim.models.keyedvectors.Vocab at 0x1fef17644e0>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1fef1764518>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x1fef1764550>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x1fef1764588>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x1fef17645c0>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x1fef17645f8>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x1fef1764630>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x1fef1764668>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x1fef17646a0>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x1fef17646d8>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x1fef1764710>,
#  'improvise': <gensim.models.keyedvectors.Vocab at 0x1fef1764748>,
#  'sequiturs': <gensim.models.keyedvectors.Vocab at 0x1fef1764780>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x1fef17647b8>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x1fef17647f0>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x1fef1764828>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x1fef1764860>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x1fef1764898>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x1fef17648d0>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x1fef1764908>,
#  'crash': <gensim.models.keyedvectors.Vocab at 0x1fef1764940>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x1fef1764978>,
#  'crib': <gensim.models.keyedvectors.Vocab at 0x1fef17649b0>,
#  'blair': <gensim.models.keyedvectors.Vocab at 0x1fef17649e8>,
#  'witch': <gensim.models.keyedvectors.Vocab at 0x1fef1764a20>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x1fef1764a58>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x1fef1764a90>,
#  'monster': <gensim.models.keyedvectors.Vocab at 0x1fef1764ac8>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x1fef1764b00>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x1fef1764b38>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x1fef1764b70>,
#  'exposition': <gensim.models.keyedvectors.Vocab at 0x1fef1764ba8>,
#  'dialogue': <gensim.models.keyedvectors.Vocab at 0x1fef1764be0>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x1fef1764c18>,
#  'subtler': <gensim.models.keyedvectors.Vocab at 0x1fef1764c50>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x1fef1764c88>,
#  'saccharine': <gensim.models.keyedvectors.Vocab at 0x1fef1764cc0>,
#  'subtexts': <gensim.models.keyedvectors.Vocab at 0x1fef1764cf8>,
#  'costume': <gensim.models.keyedvectors.Vocab at 0x1fef1764d30>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x1fef1764d68>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x1fef1764da0>,
#  'sufficient': <gensim.models.keyedvectors.Vocab at 0x1fef1764dd8>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x1fef1764e10>,
#  'mixture': <gensim.models.keyedvectors.Vocab at 0x1fef1764e48>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x1fef1764e80>,
#  'trudging': <gensim.models.keyedvectors.Vocab at 0x1fef1764eb8>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x1fef1753ba8>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x1fef1764ef0>,
#  'chris': <gensim.models.keyedvectors.Vocab at 0x1fef1764f28>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x1fef1764f60>,
#  'stereotype': <gensim.models.keyedvectors.Vocab at 0x1fef1764f98>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x1fef1764fd0>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x1fef1767048>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x1fef1767080>,
#  'exploring': <gensim.models.keyedvectors.Vocab at 0x1fef17670b8>,
#  'relationships': <gensim.models.keyedvectors.Vocab at 0x1fef17670f0>,
#  'lair': <gensim.models.keyedvectors.Vocab at 0x1fef1767128>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x1fef1767160>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x1fef1767198>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x1fef17671d0>,
#  'specifically': <gensim.models.keyedvectors.Vocab at 0x1fef1767208>,
#  'corpse': <gensim.models.keyedvectors.Vocab at 0x1fef1767240>,
#  'decorations': <gensim.models.keyedvectors.Vocab at 0x1fef1767278>,
#  'ala': <gensim.models.keyedvectors.Vocab at 0x1fef17672b0>,
#  'primitive': <gensim.models.keyedvectors.Vocab at 0x1fef17672e8>,
#  'jeepers': <gensim.models.keyedvectors.Vocab at 0x1fef1767320>,
#  'creepers': <gensim.models.keyedvectors.Vocab at 0x1fef1767358>,
#  'edited': <gensim.models.keyedvectors.Vocab at 0x1fef1767390>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1fef17673c8>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x1fef1767400>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x1fef1767438>,
#  'frightening': <gensim.models.keyedvectors.Vocab at 0x1fef1767470>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x1fef17674a8>,
#  'missteps': <gensim.models.keyedvectors.Vocab at 0x1fef17674e0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x1fef1767518>,
#  'thinks': <gensim.models.keyedvectors.Vocab at 0x1fef1767550>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x1fef1767588>,
#  'chop': <gensim.models.keyedvectors.Vocab at 0x1fef17675c0>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x1fef17675f8>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x1fef1767630>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x1fef1767668>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x1fef17676a0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1fef17676d8>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x1fef1767710>,
#  'screens': <gensim.models.keyedvectors.Vocab at 0x1fef1767748>,
#  'snippets': <gensim.models.keyedvectors.Vocab at 0x1fef1767780>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x1fef17677b8>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1fef17677f0>,
#  'unspecified': <gensim.models.keyedvectors.Vocab at 0x1fef1767828>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x1fef1767860>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x1fef1767898>,
#  'irrelevant': <gensim.models.keyedvectors.Vocab at 0x1fef17678d0>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x1fef1767908>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x1fef1767940>,
#  'occurring': <gensim.models.keyedvectors.Vocab at 0x1fef1767978>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x1fef17679b0>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x1fef17679e8>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x1fef1767a20>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x1fef1767a58>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x1fef1767a90>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x1fef1767ac8>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x1fef1767b00>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x1fef1767b38>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x1fef1767b70>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x1fef1767ba8>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x1fef1767be0>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x1fef1767c18>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x1fef1767c50>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x1fef1767c88>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1fef1767cc0>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x1fef1767cf8>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x1fef1767d30>,
#  'pointless': <gensim.models.keyedvectors.Vocab at 0x1fef1767d68>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x1fef1767da0>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x1fef1767dd8>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x1fef1767e10>,
#  'justify': <gensim.models.keyedvectors.Vocab at 0x1fef1767e48>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x1fef1767e80>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x1fef1767eb8>,
#  'humanity': <gensim.models.keyedvectors.Vocab at 0x1fef1767ef0>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x1fef1767f28>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x1fef1767f60>,
#  'mancini': <gensim.models.keyedvectors.Vocab at 0x1fef1767f98>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x1fef1767fd0>,
#  'superfluous': <gensim.models.keyedvectors.Vocab at 0x1fef176c048>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x1fef176c080>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x1fef176c0b8>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x1fef176c0f0>,
#  'porno': <gensim.models.keyedvectors.Vocab at 0x1fef176c128>,
#  'motif': <gensim.models.keyedvectors.Vocab at 0x1fef176c160>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x1fef176c198>,
#  'characters': <gensim.models.keyedvectors.Vocab at 0x1fef176c1d0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x1fef176c208>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x1fef176c240>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x1fef176c278>,
#  'stereotypes': <gensim.models.keyedvectors.Vocab at 0x1fef176c2b0>,
#  'asian': <gensim.models.keyedvectors.Vocab at 0x1fef176c2e8>,
#  'insists': <gensim.models.keyedvectors.Vocab at 0x1fef176c320>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x1fef176c358>,
#  'blurry': <gensim.models.keyedvectors.Vocab at 0x1fef176c390>,
#  'cam': <gensim.models.keyedvectors.Vocab at 0x1fef176c3c8>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x1fef176c400>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x1fef176c438>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x1fef176c470>,
#  'fog': <gensim.models.keyedvectors.Vocab at 0x1fef176c4a8>,
#  'subtle': <gensim.models.keyedvectors.Vocab at 0x1fef176c4e0>,
#  'filter': <gensim.models.keyedvectors.Vocab at 0x1fef176c518>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x1fef176c550>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x1fef176c588>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x1fef176c5c0>,
#  'fan': <gensim.models.keyedvectors.Vocab at 0x1fef176c5f8>,
#  'intrigued': <gensim.models.keyedvectors.Vocab at 0x1fef176c630>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x1fef176c668>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x1fef176c6a0>,
#  'setting': <gensim.models.keyedvectors.Vocab at 0x1fef176c6d8>,
#  'hiking': <gensim.models.keyedvectors.Vocab at 0x1fef176c710>,
#  'basically': <gensim.models.keyedvectors.Vocab at 0x1fef176c748>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x1fef176c780>,
#  'couldn': <gensim.models.keyedvectors.Vocab at 0x1fef176c7b8>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x1fef176c7f0>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x1fef176c828>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1fef176c860>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x1fef176c898>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1fef176c8d0>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x1fef176c908>,
#  'gritty': <gensim.models.keyedvectors.Vocab at 0x1fef176c940>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x1fef176c978>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x1fef176c9b0>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x1fef176c9e8>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x1fef176ca20>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x1fef176ca58>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x1fef176ca90>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x1fef176cac8>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x1fef176cb00>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x1fef176cb38>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x1fef176cb70>,
#  'directing': <gensim.models.keyedvectors.Vocab at 0x1fef176cba8>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x1fef176cbe0>,
#  'manages': <gensim.models.keyedvectors.Vocab at 0x1fef176cc18>,
#  'sci': <gensim.models.keyedvectors.Vocab at 0x1fef176cc50>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x1fef176cc88>,
#  'cliches': <gensim.models.keyedvectors.Vocab at 0x1fef176ccc0>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x1fef176ccf8>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x1fef176cd30>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x1fef176cd68>,
#  'suspense': <gensim.models.keyedvectors.Vocab at 0x1fef176cda0>,
#  'landscape': <gensim.models.keyedvectors.Vocab at 0x1fef176cdd8>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x1fef176ce10>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x1fef176ce48>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x1fef176ce80>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x1fef176ceb8>,
#  'masterpiece': <gensim.models.keyedvectors.Vocab at 0x1fef176cef0>,
#  'fashioned': <gensim.models.keyedvectors.Vocab at 0x1fef176cf28>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x1fef176cf60>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x1fef176cf98>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x1fef176cfd0>,
#  'thoroughly': <gensim.models.keyedvectors.Vocab at 0x1fef176e048>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x1fef176e080>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x1fef176e0b8>,
#  'incredibly': <gensim.models.keyedvectors.Vocab at 0x1fef176e0f0>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x1fef176e128>,
#  'predictable': <gensim.models.keyedvectors.Vocab at 0x1fef176e160>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x1fef176e198>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x1fef176e1d0>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x1fef176e208>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x1fef176e240>,
#  'gang': <gensim.models.keyedvectors.Vocab at 0x1fef176e278>,
#  'rob': <gensim.models.keyedvectors.Vocab at 0x1fef176e2b0>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x1fef176e2e8>,
#  'stations': <gensim.models.keyedvectors.Vocab at 0x1fef176e320>,
#  'rape': <gensim.models.keyedvectors.Vocab at 0x1fef176e358>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x1fef176e390>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x1fef176e3c8>,
#  'policeman': <gensim.models.keyedvectors.Vocab at 0x1fef176e400>,
#  'teenagers': <gensim.models.keyedvectors.Vocab at 0x1fef176e438>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x1fef176e470>,
#  'cliche': <gensim.models.keyedvectors.Vocab at 0x1fef176e4a8>,
#  'imaginable': <gensim.models.keyedvectors.Vocab at 0x1fef176e4e0>,
#  'hilarious': <gensim.models.keyedvectors.Vocab at 0x1fef176e518>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x1fef176e550>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x1fef176e588>,
#  'immortal': <gensim.models.keyedvectors.Vocab at 0x1fef176e5c0>,
#  'jr': <gensim.models.keyedvectors.Vocab at 0x1fef176e5f8>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x1fef176e630>,
#  'laughs': <gensim.models.keyedvectors.Vocab at 0x1fef176e668>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x1fef176e6a0>,
#  'ain': <gensim.models.keyedvectors.Vocab at 0x1fef176e6d8>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x1fef176e710>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x1fef176e748>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x1fef176e780>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x1fef176e7b8>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x1fef176e7f0>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x1fef176e828>,
#  'sickened': <gensim.models.keyedvectors.Vocab at 0x1fef176e860>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x1fef176e898>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x1fef176e8d0>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x1fef176e908>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x1fef176e940>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1fef176e978>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x1fef176e9b0>,
#  'cnn': <gensim.models.keyedvectors.Vocab at 0x1fef176e9e8>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x1fef176ea20>,
#  'abu': <gensim.models.keyedvectors.Vocab at 0x1fef176ea58>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x1fef176ea90>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x1fef176eac8>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x1fef176eb00>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x1fef176eb38>,
#  'intellectual': <gensim.models.keyedvectors.Vocab at 0x1fef176eb70>,
#  'stimulation': <gensim.models.keyedvectors.Vocab at 0x1fef176eba8>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1fef176ebe0>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x1fef176ec18>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x1fef176ec50>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x1fef176ec88>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x1fef176ecc0>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x1fef176ecf8>,
#  'guard': <gensim.models.keyedvectors.Vocab at 0x1fef176ed30>,
#  'reserves': <gensim.models.keyedvectors.Vocab at 0x1fef176ed68>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x1fef176eda0>,
#  'roughly': <gensim.models.keyedvectors.Vocab at 0x1fef176edd8>,
#  'abuses': <gensim.models.keyedvectors.Vocab at 0x1fef176ee10>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x1fef176ee48>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x1fef176ee80>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x1fef176eeb8>,
#  'stepped': <gensim.models.keyedvectors.Vocab at 0x1fef176eef0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1fef176ef28>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x1fef176ef60>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1fef176ef98>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x1fef176efd0>,
#  'sarcastic': <gensim.models.keyedvectors.Vocab at 0x1fef1772048>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x1fef1772080>,
#  'commentary': <gensim.models.keyedvectors.Vocab at 0x1fef17720b8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1fef17720f0>,
#  'enemy': <gensim.models.keyedvectors.Vocab at 0x1fef1772128>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x1fef1772160>,
#  'conflicts': <gensim.models.keyedvectors.Vocab at 0x1fef1772198>,
#  'disaster': <gensim.models.keyedvectors.Vocab at 0x1fef17721d0>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x1fef1772208>,
#  'humanitarian': <gensim.models.keyedvectors.Vocab at 0x1fef1772240>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x1fef1772278>,
#  'missions': <gensim.models.keyedvectors.Vocab at 0x1fef17722b0>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x1fef17722e8>,
#  'indonesia': <gensim.models.keyedvectors.Vocab at 0x1fef1772320>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x1fef1772358>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x1fef1772390>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x1fef17723c8>,
#  'overwhelmed': <gensim.models.keyedvectors.Vocab at 0x1fef1772400>,
#  'governments': <gensim.models.keyedvectors.Vocab at 0x1fef1772438>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x1fef1772470>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x1fef17724a8>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x1fef17724e0>,
#  'mocks': <gensim.models.keyedvectors.Vocab at 0x1fef1772518>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x1fef1772550>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x1fef1772588>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x1fef17725c0>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x1fef17725f8>,
#  'villages': <gensim.models.keyedvectors.Vocab at 0x1fef1772630>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x1fef1772668>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x1fef17726a0>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x1fef17726d8>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x1fef1772710>,
#  'landing': <gensim.models.keyedvectors.Vocab at 0x1fef1772748>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x1fef1772780>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x1fef17727b8>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x1fef17727f0>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x1fef1772828>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x1fef1772860>,
#  'unscrupulous': <gensim.models.keyedvectors.Vocab at 0x1fef1772898>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x1fef17728d0>,
#  'occupation': <gensim.models.keyedvectors.Vocab at 0x1fef1772908>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x1fef1772940>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x1fef1772978>,
#  'minds': <gensim.models.keyedvectors.Vocab at 0x1fef17729b0>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x1fef17729e8>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x1fef1772a20>,
#  'mayhem': <gensim.models.keyedvectors.Vocab at 0x1fef1772a58>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x1fef1772a90>,
#  'disservice': <gensim.models.keyedvectors.Vocab at 0x1fef1772ac8>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x1fef1772b00>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x1fef1772b38>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x1fef1772b70>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x1fef1772ba8>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x1fef1772be0>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x1fef1772c18>,
#  'entry': <gensim.models.keyedvectors.Vocab at 0x1fef1772c50>,
#  'personnel': <gensim.models.keyedvectors.Vocab at 0x1fef1772c88>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x1fef1772cc0>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x1fef1772cf8>,
#  'assuming': <gensim.models.keyedvectors.Vocab at 0x1fef1772d30>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x1fef1772d68>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x1fef1772da0>,
#  'harm': <gensim.models.keyedvectors.Vocab at 0x1fef1772dd8>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x1fef1772e10>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x1fef1772e48>,
#  'minimum': <gensim.models.keyedvectors.Vocab at 0x1fef1772e80>,
#  'wage': <gensim.models.keyedvectors.Vocab at 0x1fef1772eb8>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x1fef1772ef0>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x1fef1772f28>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x1fef1772f60>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x1fef1772f98>,
#  'nearby': <gensim.models.keyedvectors.Vocab at 0x1fef1772fd0>,
#  'visitor': <gensim.models.keyedvectors.Vocab at 0x1fef1777048>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x1fef1777080>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x1fef17770b8>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x1fef17770f0>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x1fef1777128>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x1fef1777160>,
#  'accepts': <gensim.models.keyedvectors.Vocab at 0x1fef1777198>,
#  'lieu': <gensim.models.keyedvectors.Vocab at 0x1fef17771d0>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x1fef1777208>,
#  'ged': <gensim.models.keyedvectors.Vocab at 0x1fef1777240>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x1fef1777278>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x1fef17772b0>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x1fef17772e8>,
#  'undergraduate': <gensim.models.keyedvectors.Vocab at 0x1fef1777320>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x1fef1777358>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x1fef1777390>,
#  'encouraged': <gensim.models.keyedvectors.Vocab at 0x1fef17773c8>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x1fef1777400>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1fef1777438>,
#  'elfen': <gensim.models.keyedvectors.Vocab at 0x1fef1777470>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x1fef17774a8>,
#  'hasn': <gensim.models.keyedvectors.Vocab at 0x1fef17774e0>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x1fef1777518>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x1fef1777550>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x1fef1777588>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x1fef17775c0>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x1fef17775f8>,
#  'violence': <gensim.models.keyedvectors.Vocab at 0x1fef1777630>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x1fef1777668>,
#  'haven': <gensim.models.keyedvectors.Vocab at 0x1fef17776a0>,
#  'witnessed': <gensim.models.keyedvectors.Vocab at 0x1fef17776d8>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x1fef1777710>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x1fef1777748>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x1fef1777780>,
#  'coherently': <gensim.models.keyedvectors.Vocab at 0x1fef17777b8>,
#  'pondering': <gensim.models.keyedvectors.Vocab at 0x1fef17777f0>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x1fef1777828>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x1fef1777860>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x1fef1777898>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x1fef17778d0>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x1fef1777908>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x1fef1777940>,
#  'anime': <gensim.models.keyedvectors.Vocab at 0x1fef1777978>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x1fef17779b0>,
#  'shines': <gensim.models.keyedvectors.Vocab at 0x1fef17779e8>,
#  'narrative': <gensim.models.keyedvectors.Vocab at 0x1fef1777a20>,
#  'enthralled': <gensim.models.keyedvectors.Vocab at 0x1fef1777a58>,
#  'weaving': <gensim.models.keyedvectors.Vocab at 0x1fef1777a90>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x1fef1777ac8>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x1fef1777b00>,
#  'gory': <gensim.models.keyedvectors.Vocab at 0x1fef1777b38>,
#  'encounter': <gensim.models.keyedvectors.Vocab at 0x1fef1777b70>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x1fef1777ba8>,
#  'contrasting': <gensim.models.keyedvectors.Vocab at 0x1fef1777be0>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x1fef1777c18>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x1fef1777c50>,
#  'emotive': <gensim.models.keyedvectors.Vocab at 0x1fef1777c88>,
#  'bloodshed': <gensim.models.keyedvectors.Vocab at 0x1fef1777cc0>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x1fef1777cf8>,
#  'tears': <gensim.models.keyedvectors.Vocab at 0x1fef1777d30>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x1fef1777d68>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x1fef1777da0>,
#  'viewer': <gensim.models.keyedvectors.Vocab at 0x1fef1777dd8>,
#  ...}

# %%
model.wv['day']
# Out:
# array([ 1.4759701e+00,  1.3312018e+00,  9.0469497e-01,  6.4515418e-01,
#         4.5683938e-01,  9.5819312e-01,  1.1333633e-01, -2.7829413e+00,
#        -2.6117425e+00, -2.3655633e-02, -2.6496823e+00, -2.8489287e+00,
#         4.0917106e-02,  3.8033977e-01, -2.0531213e+00, -1.1277156e+00,
#         6.4449513e-01,  1.9742483e+00,  1.5332140e+00,  8.6274683e-02,
#         2.1200922e+00, -2.0468512e+00, -1.8674213e+00, -1.1124544e+00,
#         9.0135694e-01, -1.6607662e+00, -3.2903823e-01, -3.4025457e-02,
#        -9.1189693e-04, -1.0193282e+00,  1.2224613e+00, -2.1265600e+00,
#         5.8114988e-01,  2.8652098e+00, -8.5267526e-01,  5.1921988e-01,
#        -1.4077172e+00,  2.6229343e+00, -6.8359971e-01, -6.9709319e-01,
#        -1.4589976e-01, -2.3118398e+00,  2.3111041e+00, -4.0374317e+00,
#        -1.6424408e+00,  1.7523721e-01,  3.7503698e+00,  1.6732907e+00,
#        -3.8256729e+00,  5.6548595e-01], dtype=float32)

# %%
model.wv.most_similar('great')
# Out:
# 2019-04-24 17:07:43,110 : INFO : precomputing L2-norms of word weight vectors
# [('fantastic', 0.8850609660148621),
#  ('terrific', 0.8746536374092102),
#  ('wonderful', 0.8705322742462158),
#  ('fine', 0.8432004451751709),
#  ('good', 0.8161855936050415),
#  ('brilliant', 0.8043473958969116),
#  ('superb', 0.7879005670547485),
#  ('nice', 0.7645126581192017),
#  ('marvelous', 0.7452230453491211),
#  ('amazing', 0.7448444366455078)]

# %%
model.doesnt_match("man woman child kitchen".split())
# Out:
# C:\Users\Kalle\Anaconda3\envs\fastai\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# 'kitchen'

# %%
model.wv.most_similar(positive=['man', 'child'], negative=['woman'])
# Out:
# [('kid', 0.6418389081954956),
#  ('dad', 0.5888713002204895),
#  ('teenager', 0.5855788588523865),
#  ('son', 0.585324764251709),
#  ('father', 0.580054521560669),
#  ('soldier', 0.5780121088027954),
#  ('brother', 0.5746058821678162),
#  ('parent', 0.5717295408248901),
#  ('grandfather', 0.5689224600791931),
#  ('lad', 0.5683940052986145)]

# %% [markdown]
# ## RNNs

# %% [markdown]
# ![RNN](http://karpathy.github.io/assets/rnn/charseq.jpeg)
#
# Source: http://karpathy.github.io/2015/05/21/rnn-effectiveness/

# %% [markdown]
# ### Vanilla RNN Issues
#
# - Very short memory
# - Vanishing/Exploding gradients
# - Repetition

# %% [markdown]
# How the hidden state is calculated:
#
# ![Hidden state](https://camo.githubusercontent.com/81f93073e5e2ab8d3a3ff63f847fb45be05d0395/68747470733a2f2f63646e2d696d616765732d312e6d656469756d2e636f6d2f6d61782f313434302f302a5455466e4532617243724d72437678482e706e67)
#
#
# Code source: https://gist.github.com/karpathy/d4dee566867f8291f086

# %%
import numpy as np

data = open('dumas.txt', 'r', encoding='utf8').read()

chars = list(set(data)) 
data_size, vocab_size = len(data), len(chars)
print('data has %d chars, %d unique' % (data_size, vocab_size))
# Out:
# data has 2643851 chars, 107 unique

# %%
char_to_ix = {ch:i for i,ch in enumerate(chars)}
ix_to_char = {i:ch for i, ch in enumerate(chars)}
print(char_to_ix)
# Out:
# {'e': 0, '0': 1, 'ç': 2, 'k': 3, 'Z': 4, 'J': 5, '@': 6, 'Æ': 7, ',': 8, 'a': 9, 'œ': 10, 'o': 11, 'Œ': 12, '†': 13, 'M': 14, '(': 15, '7': 16, 'd': 17, 'I': 18, 'n': 19, '—': 20, 'q': 21, 'P': 22, 'D': 23, 'G': 24, 'E': 25, 'É': 26, '8': 27, 'j': 28, 'm': 29, 'K': 30, ';': 31, '.': 32, 'u': 33, ']': 34, 'ë': 35, '9': 36, 'S': 37, 'w': 38, 'f': 39, '%': 40, 'c': 41, 'l': 42, 'V': 43, 'O': 44, 'L': 45, 'F': 46, ')': 47, 'Q': 48, '3': 49, 'C': 50, 'B': 51, 'y': 52, '[': 53, 'à': 54, 'é': 55, 'R': 56, '”': 57, 'î': 58, 'Y': 59, "'": 60, '&': 61, 'ê': 62, '-': 63, '\ufeff': 64, ' ': 65, '4': 66, 'r': 67, '\n': 68, 'X': 69, 'ï': 70, 'H': 71, ':': 72, 'æ': 73, '$': 74, 'h': 75, 'N': 76, 'U': 77, 'W': 78, '5': 79, 'z': 80, 'è': 81, 'í': 82, '’': 83, 'g': 84, '‘': 85, 't': 86, 'T': 87, '#': 88, '*': 89, 'â': 90, '1': 91, 's': 92, '/': 93, 'ô': 94, 'b': 95, '?': 96, 'x': 97, 'ü': 98, '“': 99, 'v': 100, 'A': 101, 'i': 102, '!': 103, '2': 104, '6': 105, 'p': 106}

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
    """
    inputs,targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    # forward pass
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# ![RNN](https://cdn-images-1.medium.com/max/1600/1*T_ECcHZWpjn0Ki4_4BEzow.gif)
#
# Unrolling it:
#
# ![Unrolled](https://cdn-images-1.medium.com/max/1600/1*TqcA9EIUF-DGGTBhIx_qbQ.gif)
#
# Source: https://towardsdatascience.com/illustrated-guide-to-recurrent-neural-networks-79e5eb8049c9

# %% [markdown]
# ![Vanilla](https://www.learnopencv.com/wp-content/uploads/2017/10/mlp-diagram.jpg)
#
# Source: https://www.learnopencv.com

# %%
def sample(h, seed_ix, n):
    """ 
    sample a sequence of integers from the model 
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    txt = ''.join(ix_to_char[ix] for ix in ixes)
    print('----\n %s \n----' % (txt, ))
    
hprev = np.zeros((hidden_size,1)) # reset RNN memory  
#predict the 200 next characters given 'a'
sample(hprev,char_to_ix['a'],200)
# Out:
# ----
#  æ9j
# gâPLLLmz3G)É)n﻿n’ jrt'âLÉæ;,bQv@﻿8V)lF,)tj7﻿dïKA!ç.æ’
# J‘FF0﻿sw-mÉÉp“)“’@nk'ïN/WŒf‘ütYz'eëI†uap;” RXxG ]kÆJuQDRN]Eee8é0%Aayzv6@20f﻿p‘bY9Ií-Y12$W!k#Nn.P“ŒuC0ü(HHY%œu:”w%—êAuX):“﻿;)‘é5ë1ÆK&$asS?(g4Cd
# ----

# %%
p=0  
inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
print("inputs", inputs)
targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]
print("targets", targets)
# Out:
# inputs [64, 22, 67, 11, 28, 0, 41, 86, 65, 24, 33, 86, 0, 19, 95, 0, 67, 84, 60, 92, 65, 87, 75, 0, 65]
# targets [22, 67, 11, 28, 0, 41, 86, 65, 24, 33, 86, 0, 19, 95, 0, 67, 84, 60, 92, 65, 87, 75, 0, 65, 50]

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad                                                                                                                
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0                                                                                                                        
#while n<=1000*100:
while n<=200:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    # check "How to feed the loss function to see how this part works
    if p+seq_length+1 >= len(data) or n == 0:
        hprev = np.zeros((hidden_size,1)) # reset RNN memory                                                                                                                                      
        p = 0 # go from start of data                                                                                                                                                             
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    # forward seq_length characters through the net and fetch gradient                                                                                                                          
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001

    # sample from the model now and then                                                                                                                                                        
    if n % 1000 == 0:
        print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
        sample(hprev, inputs[0], 200)

    # perform parameter update with Adagrad                                                                                                                                                     
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by],
                                    [dWxh, dWhh, dWhy, dbh, dby],
                                    [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update                                                                                                                   

    p += seq_length # move data pointer                                                                                                                                                         
    n += 1 # iteration counter
# Out:
# iter 0, loss: 116.858822
# ----
#  QtS*Q[S*glS*† S*”RS*TFS*jPS*1eS9ôRSU†eS* LS*†SS*uSS*oSS*o'S*†:S*h0S*QRS*Q#S*m-S*ô
# S*TtS*ôSS*ôwS*QSS*Y'SWpoS*†,S*PèS*GaS*Q.S*QFS*TtS*QgS*†tS*Q S8Z
# S*†
# S*ÉRS*ujS*QRS*cdS*QFS*ZlS*ôRS*†SS*TFS*LlS*g
# S*ô1S*
# ----
